# %% [markdown]
# #━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# # ONE-TIME CONSOLIDATED SETUP SCRIPT (ALREADY EXECUTED)
# #━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %%
# %sql
CREATE CATALOG IF NOT EXISTS databricks_project;
USE CATALOG databricks_project

# %%
# %sql
  CREATE SCHEMA IF NOT EXISTS rgr_storage;
  CREATE VOLUME IF NOT EXISTS databricks_project.rgr_storage.bronze;
  CREATE VOLUME IF NOT EXISTS databricks_project.rgr_storage.silver;
  CREATE VOLUME IF NOT EXISTS databricks_project.rgr_storage.gold;
  CREATE VOLUME IF NOT EXISTS databricks_project.rgr_storage.working_labs;

# %%
dbutils.notebook.exit("Success")
