# %% [markdown]
# - <a href="https://docs.databricks.com/en/notebooks/index.html">**Notebooks Documentation**</a>
#
# Notebook Name : 01-Notebook-Introduction
#
# | Magic Command | Language Selection |
# | --- | --- |
# | %md  | Markdown language |
# | %py  | Python language |
# | %sql | SQL |
# | %scala | Scala or Java Language |
# | %R | R Programming Language |

# %%
dbutils.notebook.exit("Success")
